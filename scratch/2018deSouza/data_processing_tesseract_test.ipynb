# %%
from pdf2image import convert_from_path
from pytesseract import image_to_string
from PIL import Image
import os

# %%
print(f"Current working directory: {os.getcwd()}")

base_path = "papers/2018deSouza"
filename = "2018deSouza_supplementarry_information.pdf"

file_path = os.path.join(os.getcwd(), base_path, filename)
print(f"Full filepath: {file_path}")
# Out:
# Current working directory: /Users/jamesbyers/code/github/Kaggle/openai_to_z
# Full filepath: /Users/jamesbyers/code/github/Kaggle/openai_to_z/papers/2018deSouza/2018deSouza_supplementarry_information.pdf

# %%
def extract_text_from_pdf(pdf_path, dpi=300, page_nums=None):
    print(f"Converting pages {page_nums} of PDF to images...")
    images = convert_from_path(
        pdf_path,
        dpi=dpi,
        first_page=min(page_nums),
        last_page=max(page_nums)
    )
    print(f"Converted {len(images)} pages to images.")

    all_text = []

    for i, image in enumerate(images):
        actual_page = page_nums[i]
        print(f"Processing OCR on page {actual_page}...")
        text = image_to_string(image, config='--psm 6')
        all_text.append((actual_page, text))
        print(f"Finished OCR for page {actual_page}.")

    print("Finished processing all pages.")
    return all_text

pdf_path = file_path
pages_to_extract = [8, 9, 10]
extracted = extract_text_from_pdf(pdf_path, page_nums=pages_to_extract)
# Out:
# Converting pages [8, 9, 10] of PDF to images...
# Converted 3 pages to images.
# Processing OCR on page 8...
# Finished OCR for page 8.
# Processing OCR on page 9...
# Finished OCR for page 9.
# Processing OCR on page 10...
# Finished OCR for page 10.
# Finished processing all pages.
# --- Page 8 ---
# Supplementary Table 4. Archaeological sites identified in the Upper Tapajés Basin.
#
# Population estimates were calculated based on the linear equation described in Curet **.
#
# Site Structure Type Latitude Longitude thay opulation
#
# Mto1 l circular enclosure -57.9452  -9.4071 1.61 239
# hexagonal
#
# Mto2 l enclosure -57.8872 -9.8711 3.18 454
#
# Mto3 l circular enclosure  -57.8772 -9.7048 5.11 719
#
# Mto4 l enclosure -57.8212 -9.8132 2.41 349
#
# Mto5 l circular enclosure -57.7557 = -9.8221 1.77 262
#
# Mt06 | circular enclosure -58.2325 -9.4150 1.82 268
#
# Mto6 Il enclosure -58.2326 -9.4149 ;
#
# Mt07 l circular enclosure -59.3228 -9.3501
#
# Mto7 ll circular enclosure -59.3208 -9.3512 9.88 1373
#
# Mto7 ll causeway -59.3146 -9.3476
#
# Mtos l circular enclosure  -59.2340 -9.4506 0.9 143
#
# Mt09 | circular enclosure  -58.6019  -9.9833 0.79 127
# hexagonal
#
# Mt10 | enclosure 58.4585 -10.0984 1° 258
#
# Mt11 l circular enclosure -58.6438 -10.3111 2.07 302
# hexagonal
#
# Mt12 | enclosure 57.3703 -9.4245 3-47 494
#
# Mti3 I circular enclosure -58.4414  -10.7534 0.13 37
# hexagonal
#
# Mt14 | enclosure _-59.6343_-10.0918 _%88 962
#
# Mti6 | circular enclosure _-58.5072 _-10.3604 0.16 41
# hexagonal
#
# Mtt7 | enclosure 57.9857 -9.7611 94 298
#
# Mti8 | enclosure _-57.8512 _-9.4176 4.53 639
#
# Mt19 | circular enclosure  -57.8374 -9.5936 0.1 33
#
# Mt20 l enclosure -57.7716  -9.8721 1.01 157
#
# Mt21 | circular enclosure -59.0036 -9.4852 0.48 85
#
# Mt23 | circular enclosure -55.2413 -9.9197 1.59 236
#
# Mt24 | causeway -55.5070 = -9.6730
#
# Mt25/26 l circular enclosure -58.5124 -9.9246 0.29 58
#
# Mt25/26 Il circular enclosure -58.5100  -9.9231 ;
#
# Mt27 l circular enclosure -59.1692 -9.4302 0.45 81
#
# Mt27 H] circular enclosure -59.1690 -9.4304 ;
#
# Mt28 l circular enclosure -59.2405 -9.3650 0.49 87
#
# Mt29 l circular enclosure -59.3187 -9.2897 0.77 425
#
# Mt29 HI causeway -59.3240 -9.2909 ;
#
# Mts0 l mounded village -59.3287 -9.4957 0.77 125
# hexagonal
#
# Mt-31 | enclosure -60.0786 -9.9671 2.11 308
#
# Mt-32 | enclosure -57.9185 -9.7542 2.63 379
#
# Mt-33 | circularenclosure -58.5755 -10.0513 0.21 48
#
# Mt-34 | circularenclosure -58.5713 -10.1108 0.06 28
#
# Mt-35/36 | enclosure “58.5775 -10.0298 4, 53
#
# Mt-35/36 iI circularenclosure -58.5766 -10.0297 ,
#
# Mt-37 | circularenclosure -58.5424 -10.2691 0.19 45
#
# NN | enclosure -59.0066 -9.4575 1.54 230
#
# Z-Mt01 l circular enclosure -58.1495  -9.7471 4.76 671
#
# Z-Mt01 ll enclosure -58.1493 -9.7476 ;
#
# --- Page 9 ---
# Z-Mt01 Il circular enclosure -58.1500 -9.7489
#
# Z-Mt01 IV circular enclosure  -58.1499 -9.7494
#
# Z-Mto2 l circular enclosure -58.1425  -10.1667 5.27 741
# hexagonal
#
# Z-Mt0o3 | enclosure 57.7843 -9.5961 349 489
# hexagonal
#
# Z-Mt04 | enclosure -57.6745 -9.8635 18.79 2594
#
# Z-Mt04 II enclosure -57.6760 -9.8654
#
# Z-Mt05 | circular enclosure -58.3389 -9.3335 3.44 486
#
# Z-Mt05 Il circular enclosure -58.3391 = -9.3329 ;
#
# Z-Mt06 | enclosure -58.2823 -9.4370 3.6 512
#
# Z-Mt07 l circular enclosure -58.1723  -9.4871 1.15 177
# hexagonal
#
# Z-Mtog8 | enclosure 58.1557 -9.4419 ‘|! 198
#
# Z-Mt09/10 | circular enclosure -58.8590 -9.2415
#
# Z-Mt09/10 Il circular enclosure -58.8576 -9.2446 0.59 400
#
# Z-Mt09/10 _ Ill circular enclosure -58.8564 -9.2429 ‘
#
# Z-Mt09/10 IV circular enclosure -58.8565 -9.2427
#
# Z-Mt11 l circular enclosure -58.9347 -9.2116 0.35 67
#
# Z-Mt11 II circular enclosure -58.9350 -9.2115 ;
#
# Z-Mt12 | enclosure -59.0231 -9.0253 3.34 477
#
# Z-Mti2 Il circular enclosure  -59.0221 -9.0253 ;
#
# Z-Mt13 | circular enclosure -59.0994 -9.0478 0.73 119
#
# Z-Mt14 l circular enclosure -59.0988 -9.3029
#
# Z-Mt14 Il causeway -59.1009 -9.2996 0.14 38
#
# Z-Mt14 Il causeway _-59.0970 _ -9.3012
#
# Z-Mt15 | circular enclosure _-59.0958 —_-9.3129 0.04 25
#
# Z-Mti6 l circular enclosure -59.1055 -9.0507
#
# Z-Mt16 Il circular enclosure -59.1072 -9.0509 0.37 70
#
# Z-Mti6 HI circular enclosure _-59.1049 —_-9.0497
#
# Z-Mt19 | circular enclosure _-58.4527 —_-9.9663 0.14 38
#
# Z-Mt20 | circular enclosure _-58.3285 —_-10.3927 0.1 32
#
# Z-Mt21 | enclosure -57.4240 -9.1798 8.92 1241
#
# Z-Mt22 | circular enclosure -59.7402 -9.3220 0.15 39
#
# Z-Mt23 l circular enclosure -59.7501 -9.4271 1.27 193
#
# Z-Mt24/25 | circular enclosure -59.7943 -9.5016 2412 309
#
# Z-Mt24/25 Il enclosure -59.7980 -9.5016 ;
#
# Z-Mt25/26 Il enclosure -59.8014 -9.4867 0.51 88
#
# Z-Mt26 l circular enclosure -59.8006 -9.4867 0.82 131
#
# Z-Mt27 | circular enclosure -59.8122 -9.5065 2.44 353
# hexagonal
#
# Z-Mi28 | enclosure 57.1729 -9.7239 +99 703
#
# Z-Mt29 l circular enclosure -57.9733  -9.7970 0.11 34
# hexagonal
#
# Z-Mt30 | enclosure 57.9374 -10.1606 |" 227
#
# Z-Mt31 | enclosure -57.7010 -9.2278 3.37 480
# hexagonal
#
# Z-Mi32— | enclosure 57.6511 -9.6583 1"! 185
#
# Z-Mt33 l circular enclosure -58.9042 -9.2813 0.25 53
#
# Z-Mt33 H enclosure -58.9044 -9.2816 ;
#
# Z-Mt34 | mounded village -59.2797 -9.4404
#
# Z-Mt35 l circular enclosure -58.2266 -9.5330 0.12 36
#
# Z-Mt36 | enclosure -59.7847 -9.9606 1.17 180
#
# Z-Mt37 | circular enclosure -59.8073 -9.8468 0.4 74
#
# Z-Mt38 l circular enclosure -59.0461 = -9.5301 0.37 69
#
# Z-Mt38 Il circular enclosure -59.0465 -9.5302 ;
#
# Z-Mt39 | circularenclosure -60.2005 -9.6139 0.31 62
#
# Z-Mt40 | circularenclosure -58.0065 -9.5131 0.14 39
#
# --- Page 10 ---
# Z-Mt41 | enclosure -58.427 -10.6544 4.71 665
# Z-Mt42 | circular enclosure -59.0987 -9.3028 0.13 37
# Z-Mt43 | circular enclosure -58.8564 -9.243
#
# Z-Mt43 H} circular enclosure -58.8565 -9.2426 0.46 141
# Z-Mt43 ll circular enclosure  -58.859 -9,2415
#
# Z-Mt43 IV circular enclosure -58.8575 -9.2446
#
# Z-Mt44 | circularenclosure -58.1381 -9.2874 0.07 29
# Z-Mt45 | enclosure -59.0954 -9.6312 0.3 60
# Z-Mt46 | enclosure -58.8959 = -9.3249 0.19 46

# %%
# Assume `extracted` is a list of (page_num, text) tuples
# or a list of strings, or lists of strings

def flatten_text(extracted):
    lines = []

    for item in extracted:
        if isinstance(item, tuple):
            _, content = item
        else:
            content = item

        if isinstance(content, list):
            for sub in content:
                lines.append(str(sub))
        else:
            lines.append(str(content))

    return "\n".join(lines)

raw_text = flatten_text(extracted)

# %%
import re
import json
from collections import defaultdict

# Paste your raw text as a string here
raw_text = """PASTE YOUR RAW TEXT HERE"""

# Normalise characters misread by OCR
def normalise(text):
    return (
        text
        .replace("=", "-")
        .replace("Il", "II").replace("lI", "II")
        .replace("ll", "II").replace("l", "I").replace("I|", "I")
        .replace("H]", "II").replace("HI", "III")
        .replace("|", "I").replace("“", "").replace("”", "")
        .replace("‘", "").replace("’", "")
        .replace("°", "").replace("+", ".").replace(",", ".")
    )

# Clean and extract entries
lines = normalise(raw_text).splitlines()
site_data = defaultdict(list)

site_re = re.compile(
    r"(?P<site>Z?-?Mt[\d/-]+)[\s\-]*I{1,4}\b.*?"
    r"(?P<type>circular enclosure|mounded village|causeway|enclosure|circularenclosure)?"
    r"\s*(-?(?:\d{1,3}\.\d+))\s+(-?(?:\d{1,3}\.\d+))"  # lat long
    r"(?:\s+(\d+(?:\.\d+)?))?"                        # area (optional)
    r"(?:\s+(\d+))?"                                  # population (optional)
)

structure_index = defaultdict(int)

for line in lines:
    match = site_re.search(line)
    if not match:
        continue

    site_id_raw = match.group(1).replace("Z-", "").replace("--", "-")
    site_base = re.sub(r"[/-].*", "", site_id_raw)
    structure_index[site_base] += 1
    structure_num = structure_index[site_base]

    site_entry = {
        "site": site_base,
        "structure": ["I", "II", "III", "IV", "V"][structure_num - 1],
        "type": match.group(2).replace("circularenclosure", "circular enclosure") if match.group(2) else "enclosure",
        "latitude": float(match.group(3)),
        "longitude": float(match.group(4)),
        "area_ha": float(match.group(5)) if match.group(5) else None,
        "potential_population": int(match.group(6)) if match.group(6) else None,
    }

    site_data[site_base].append(site_entry)

# Output JSON
with open("parsed_sites.json", "w") as f:
    json.dump(site_data, f, indent=2)
