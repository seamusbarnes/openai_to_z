# %%
import os
import sys
import json

import rasterio
import numpy as np
import matplotlib.pyplot as plt
import rvt
import pandas as pd
from time import sleep

# %%
# compute absolute path to the project root's src/
sys.path.insert(0, os.path.join(os.getcwd(), "src"))

# import project specific (src/project_utils/...) packages #
from project_utils import config as proj_config
from project_utils import io as proj_io
from project_utils import geo as proj_geo
from project_utils import lidar as proj_lidar
from project_utils import raster as proj_raster
from project_utils import satellite as proj_satellite
from project_utils import vis as proj_vis
from project_utils import scratch as proj_scratch

# auto-reload any module that changes on disk
# %load_ext autoreload
# %autoreload
# %reload_ext autoreload

# %%
PATH_TO_CONFIG = "main/config.yml"

config = proj_config.Config(PATH_TO_CONFIG)

# %%
# download dataset metadata and csv
concept_id = config.get("dataset", "concept_id")
# doi = config.get("dataset", "doi")
path_to_csv_dir = config.get("paths", "dataset_csv")
# metadata = earthaccess.search_datasets(doi=doi)[0]
path_to_csv = proj_io.download_earthaccess_dataset_csv(
    concept_id,
    path_to_csv_dir,
    overwrite=False
    )
# Out:
# [io] Downloading dataset CSV for concept_id: C2398128915-ORNL_CLOUD
# QUEUEING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/1 [00:00<?, ?it/s]
# [io] CSV downloaded: data/metadata/cms_brazil_lidar_tile_inventory.csv

# %%
df = pd.read_csv(path_to_csv)
print(df.head(1))
print("\nMetadata dataframe columns")
print("--------------------")
for column in df.columns:
    print(column)
# Out:
#                  filename   max_lat   min_lat    max_lon    min_lon  \
# 0  ANA_A01_2017_laz_0.laz -3.363488 -3.372548 -54.992912 -55.001927
#
#     file_type  file_size_mb file_format  version   created utmzone  \
# 0  pointcloud     85.374953     LAS/LAZ      1.2  214/2017     21S
#
#                                                  srs
# 0  +proj=utm +zone=21 +south +ellps=GRS80 +towgs8...
#
# Metadata dataframe columns
# --------------------
# filename
# max_lat
# min_lat
# max_lon
# min_lon
# file_type
# file_size_mb
# file_format
# version
# created
# utmzone
# srs

# %%
index = 0
row = df.iloc[index]
filename_laz = row["filename"]

path_to_laz = proj_io.fetch_laz_file(
    filename_laz,
    config.get("paths", "raw", "laz"),
    verbose=False,
    overwrite=True
)
# Out:
# [io] Downloading ANA_A01_2017_laz_0.laz...

# %%
# print(f"Filename: {filename_laz}")
# counts, total = proj_lidar.get_laz_classification_counts(path_to_laz)
# proj_lidar.print_laz_classification_counts(counts, total)
# Out:
# Filename: ANA_A01_2017_laz_0.laz
# Class Code      Count    Percent  Name
# --------------------------------------
# 1            20671408     99.02%  Unclassified
# 2              205624      0.98%  Ground
# --------------------------------------
# TOTAL        20877032    100.00%

# %%
import geographiclib
from geographiclib.geodesic import Geodesic

def bbox_area_m2(min_lat, max_lat, min_lon, max_lon):
    poly = [
        (min_lat, min_lon),
        (min_lat, max_lon),
        (max_lat, max_lon),
        (max_lat, min_lon),
        (min_lat, min_lon),
    ]
    geod = Geodesic.WGS84
    g = geod.Polygon()
    for lat, lon in poly:
        g.AddPoint(lat, lon)
    num, perimeter, area = g.Compute()
    return abs(area)

# %%
def get_metadata(
    path_to_laz, 
    tile_area_m2, 
    all_classes=range(0,20), 
    ground_class=2
):
    """
    Compute stats for a LAZ tile. Returns a dict with keys:
        - n_points_total
        - class_{i}_count, class_{i}_pct for i in all_classes
        - n_points_ground, ground_pct, ...
        - density_total, density_ground
        - z_min, z_max, z_mean, z_std (all points)
        - z_ground_min, z_ground_max, z_ground_mean, z_ground_std
        - intensity_min, intensity_max, intensity_mean, intensity_std
        - only_return_pct
        - scan_angle_min, scan_angle_max, scan_angle_mean, scan_angle_std
        - gps_time_min, gps_time_max
    """
    import laspy
    import numpy as np
    meta = {}
    with laspy.open(path_to_laz) as lfile:
        las = lfile.read()
        classifications = np.asarray(las.classification)
        n_total = len(classifications)
        meta['n_points_total'] = n_total

        # Class stats
        unique_classes, counts = np.unique(classifications, return_counts=True)
        class_count_dict = dict(zip(unique_classes, counts))
        for cls in all_classes:
            cnt = class_count_dict.get(cls, 0)
            meta[f'class_{cls}_count'] = int(cnt)
            meta[f'class_{cls}_pct'] = (float(cnt) / n_total) if n_total else 0.0

        meta['n_points_ground'] = meta[f'class_{ground_class}_count']
        meta['ground_pct'] = meta[f'class_{ground_class}_pct']
        for k, v in zip(
            ["unclassified", "veg_low", "veg_med", "veg_high"],
            [1, 3, 4, 5]
        ):
            meta[f'n_points_{k}'] = meta.get(f'class_{v}_count', 0)

        meta['tile_area_m2'] = tile_area_m2
        meta['density_total'] = n_total / tile_area_m2 if tile_area_m2 > 0 else np.nan
        meta['density_ground'] = meta['n_points_ground'] / tile_area_m2 if tile_area_m2 > 0 else np.nan

        z = np.asarray(las.z)
        meta['z_min'] = float(z.min())
        meta['z_max'] = float(z.max())
        meta['z_mean'] = float(z.mean())
        meta['z_std'] = float(z.std())

        ground_z = z[classifications == ground_class]
        if ground_z.size > 0:
            meta['z_ground_min'] = float(ground_z.min())
            meta['z_ground_max'] = float(ground_z.max())
            meta['z_ground_mean'] = float(ground_z.mean())
            meta['z_ground_std'] = float(ground_z.std())
        else:
            for f in ['z_ground_min','z_ground_max','z_ground_mean','z_ground_std']:
                meta[f] = np.nan

        # Intensity
        inten = getattr(las, "intensity", None)
        if inten is not None:
            inten = np.asarray(inten)
            meta['intensity_min'] = float(inten.min())
            meta['intensity_max'] = float(inten.max())
            meta['intensity_mean'] = float(inten.mean())
            meta['intensity_std'] = float(inten.std())
        else:
            for f in ['intensity_min', 'intensity_max', 'intensity_mean', 'intensity_std']:
                meta[f] = np.nan

        # Only-return
        try:
            return_number = np.asarray(las.return_number)
            num_returns = np.asarray(las.number_of_returns)
            only_return = (return_number == num_returns)
            meta['only_return_pct'] = only_return.sum() / n_total if n_total else 0
        except Exception:
            meta['only_return_pct'] = np.nan

        # Scan angle
        scan = getattr(las, 'scan_angle', None)
        if scan is not None:
            scan = np.asarray(scan)
            meta['scan_angle_min'] = float(scan.min())
            meta['scan_angle_max'] = float(scan.max())
            meta['scan_angle_mean'] = float(scan.mean())
            meta['scan_angle_std'] = float(scan.std())
        else:
            for f in ['scan_angle_min','scan_angle_max','scan_angle_mean','scan_angle_std']:
                meta[f] = np.nan

        gps = getattr(las, 'gps_time', None)
        if gps is not None:
            gps = np.asarray(gps)
            meta['gps_time_min'] = float(gps.min())
            meta['gps_time_max'] = float(gps.max())
        else:
            meta['gps_time_min'] = meta['gps_time_max'] = np.nan

    return meta

# %%
area_m2 = bbox_area_m2(row['min_lat'], row['max_lat'], row['min_lon'], row['max_lon'])
meta = get_metadata(path_to_laz, tile_area_m2=area_m2)
print(type(meta))
# Out:
# <class 'dict'>

# %%
results = []
output_csv = "temp.csv"
if os.path.isfile(output_csv):
    os.remove(output_csv)
count = 0
for idx, row in df.iterrows():
    try:
        filename_laz = row["filename"]
        laz_dir = config.get("paths", "raw", "laz")
        print(f"Downloading {filename_laz} into directory {laz_dir}")

        path_to_laz = proj_io.fetch_laz_file(
            filename_laz,      # the filename onl
            laz_dir,           # the target directory only
            verbose=False,
            overwrite=True
        )
        area_m2 = bbox_area_m2(row['min_lat'], row['max_lat'], row['min_lon'], row['max_lon'])
        meta = get_metadata(path_to_laz, tile_area_m2=area_m2)

        row_out = row.to_dict()

        # Merge all meta data
        row_out.update(meta)
        results.append(row_out)

        os.remove(path_to_laz)  # Enable when ready

    except Exception as e:
        print(f"Failed for {filename_laz}: {e}")
        continue

    # Optional: Sleep
    sleep(0.1)

    # Save progress often
    if (idx+1) % 10 == 0 or (idx+1) == len(df):
        pd.DataFrame(results).to_csv(output_csv, index=False)
        print(f"Progress saved at {idx+1}/{len(df)} files.")
    count += 1

# Final save
pd.DataFrame(results).to_csv(output_csv, index=False)
print("DONE and saved to", output_csv)
# Out:
# Downloading ANA_A01_2017_laz_0.laz into directory data/raw/tiles/laz
# [io] Downloading ANA_A01_2017_laz_0.laz...
# Downloading ANA_A01_2017_laz_1.laz into directory data/raw/tiles/laz
# [io] Downloading ANA_A01_2017_laz_1.laz...
# Downloading ANA_A01_2017_laz_10.laz into directory data/raw/tiles/laz
# [io] Downloading ANA_A01_2017_laz_10.laz...
# Downloading ANA_A01_2017_laz_11.laz into directory data/raw/tiles/laz
# [io] Downloading ANA_A01_2017_laz_11.laz...
# Downloading ANA_A01_2017_laz_12.laz into directory data/raw/tiles/laz
# [io] Downloading ANA_A01_2017_laz_12.laz...
# Downloading ANA_A01_2017_laz_2.laz into directory data/raw/tiles/laz
# [io] Downloading ANA_A01_2017_laz_2.laz...
# Downloading ANA_A01_2017_laz_3.laz into directory data/raw/tiles/laz
# [io] Downloading ANA_A01_2017_laz_3.laz...
# Downloading ANA_A01_2017_laz_4.laz into directory data/raw/tiles/laz
# [io] Downloading ANA_A01_2017_laz_4.laz...
# Downloading ANA_A01_2017_laz_5.laz into directory data/raw/tiles/laz
# [io] Downloading ANA_A01_2017_laz_5.laz...
# Downloading ANA_A01_2017_laz_6.laz into directory data/raw/tiles/laz
# [io] Downloading ANA_A01_2017_laz_6.laz...
# Progress saved at 10/3152 files.
# Downloading ANA_A01_2017_laz_7.laz into directory data/raw/tiles/laz
# [io] Downloading ANA_A01_2017_laz_7.laz...
# Downloading ANA_A01_2017_laz_8.laz into directory data/raw/tiles/laz
# [io] Downloading ANA_A01_2017_laz_8.laz...
# Downloading ANA_A01_2017_laz_9.laz into directory data/raw/tiles/laz
# [io] Downloading ANA_A01_2017_laz_9.laz...
# Downloading ANA_A01_2018_LAS_0.laz into directory data/raw/tiles/laz
# [io] Downloading ANA_A01_2018_LAS_0.laz...
# Downloading ANA_A01_2018_LAS_1.laz into directory data/raw/tiles/laz
# [io] Downloading ANA_A01_2018_LAS_1.laz...
# Downloading ANA_A01_2018_LAS_10.laz into directory data/raw/tiles/laz
# [io] Downloading ANA_A01_2018_LAS_10.laz...
# Downloading ANA_A01_2018_LAS_11.laz into directory data/raw/tiles/laz
# [io] Downloading ANA_A01_2018_LAS_11.laz...
# Downloading ANA_A01_2018_LAS_2.laz into directory data/raw/tiles/laz
# [io] Downloading ANA_A01_2018_LAS_2.laz...
# Downloading ANA_A01_2018_LAS_3.laz into directory data/raw/tiles/laz
# [io] Downloading ANA_A01_2018_LAS_3.laz...
# Downloading ANA_A01_2018_LAS_4.laz into directory data/raw/tiles/laz
# [io] Downloading ANA_A01_2018_LAS_4.laz...
# Progress saved at 20/3152 files.
# Downloading ANA_A01_2018_LAS_5.laz into directory data/raw/tiles/laz
# [io] Downloading ANA_A01_2018_LAS_5.laz...
# Downloading ANA_A01_2018_LAS_6.laz into directory data/raw/tiles/laz
# [io] Downloading ANA_A01_2018_LAS_6.laz...
# Downloading ANA_A01_2018_LAS_7.laz into directory data/raw/tiles/laz
# [io] Downloading ANA_A01_2018_LAS_7.laz...
# Downloading ANA_A01_2018_LAS_8.laz into directory data/raw/tiles/laz
# [io] Downloading ANA_A01_2018_LAS_8.laz...
# Downloading ANA_A01_2018_LAS_9.laz into directory data/raw/tiles/laz
# [io] Downloading ANA_A01_2018_LAS_9.laz...
# Downloading AND_A01_2013_laz_0.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2013_laz_0.laz...
# Downloading AND_A01_2013_laz_1.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2013_laz_1.laz...
# Downloading AND_A01_2013_laz_10.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2013_laz_10.laz...
# Downloading AND_A01_2013_laz_11.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2013_laz_11.laz...
# Downloading AND_A01_2013_laz_12.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2013_laz_12.laz...
# Progress saved at 30/3152 files.
# Downloading AND_A01_2013_laz_13.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2013_laz_13.laz...
# Downloading AND_A01_2013_laz_14.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2013_laz_14.laz...
# Downloading AND_A01_2013_laz_2.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2013_laz_2.laz...
# Downloading AND_A01_2013_laz_3.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2013_laz_3.laz...
# Downloading AND_A01_2013_laz_4.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2013_laz_4.laz...
# Downloading AND_A01_2013_laz_5.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2013_laz_5.laz...
# Downloading AND_A01_2013_laz_6.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2013_laz_6.laz...
# Downloading AND_A01_2013_laz_7.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2013_laz_7.laz...
# Downloading AND_A01_2013_laz_8.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2013_laz_8.laz...
# Downloading AND_A01_2013_laz_9.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2013_laz_9.laz...
# Progress saved at 40/3152 files.
# Downloading AND_A01_2013_laz_optional_0.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2013_laz_optional_0.laz...
# Downloading AND_A01_2013_laz_optional_1.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2013_laz_optional_1.laz...
# Downloading AND_A01_2013_laz_optional_10.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2013_laz_optional_10.laz...
# Downloading AND_A01_2013_laz_optional_11.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2013_laz_optional_11.laz...
# Downloading AND_A01_2013_laz_optional_12.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2013_laz_optional_12.laz...
# Downloading AND_A01_2013_laz_optional_13.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2013_laz_optional_13.laz...
# Downloading AND_A01_2013_laz_optional_14.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2013_laz_optional_14.laz...
# Downloading AND_A01_2013_laz_optional_2.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2013_laz_optional_2.laz...
# Downloading AND_A01_2013_laz_optional_3.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2013_laz_optional_3.laz...
# Downloading AND_A01_2013_laz_optional_4.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2013_laz_optional_4.laz...
# Progress saved at 50/3152 files.
# Downloading AND_A01_2013_laz_optional_5.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2013_laz_optional_5.laz...
# Downloading AND_A01_2013_laz_optional_6.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2013_laz_optional_6.laz...
# Downloading AND_A01_2013_laz_optional_7.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2013_laz_optional_7.laz...
# Downloading AND_A01_2013_laz_optional_8.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2013_laz_optional_8.laz...
# Downloading AND_A01_2013_laz_optional_9.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2013_laz_optional_9.laz...
# Downloading AND_A01_2017_LAS_0.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2017_LAS_0.laz...
# Downloading AND_A01_2017_LAS_1.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2017_LAS_1.laz...
# Downloading AND_A01_2017_LAS_10.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2017_LAS_10.laz...
# Downloading AND_A01_2017_LAS_11.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2017_LAS_11.laz...
# Downloading AND_A01_2017_LAS_12.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2017_LAS_12.laz...
# Progress saved at 60/3152 files.
# Downloading AND_A01_2017_LAS_13.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2017_LAS_13.laz...
# Downloading AND_A01_2017_LAS_14.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2017_LAS_14.laz...
# Downloading AND_A01_2017_LAS_2.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2017_LAS_2.laz...
# Downloading AND_A01_2017_LAS_3.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2017_LAS_3.laz...
# Downloading AND_A01_2017_LAS_4.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2017_LAS_4.laz...
# Downloading AND_A01_2017_LAS_5.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2017_LAS_5.laz...
# Downloading AND_A01_2017_LAS_6.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2017_LAS_6.laz...
# Downloading AND_A01_2017_LAS_7.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2017_LAS_7.laz...
# Downloading AND_A01_2017_LAS_8.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2017_LAS_8.laz...
# Downloading AND_A01_2017_LAS_9.laz into directory data/raw/tiles/laz
# [io] Downloading AND_A01_2017_LAS_9.laz...
# Progress saved at 70/3152 files.
# Downloading ANT_A01_2011_laz_0.laz into directory data/raw/tiles/laz
# [io] Downloading ANT_A01_2011_laz_0.laz...
# Downloading ANT_A01_2011_laz_1.laz into directory data/raw/tiles/laz
# [io] Downloading ANT_A01_2011_laz_1.laz...
# Downloading ANT_A01_2011_laz_10.laz into directory data/raw/tiles/laz
# [io] Downloading ANT_A01_2011_laz_10.laz...
# Downloading ANT_A01_2011_laz_11.laz into directory data/raw/tiles/laz
# [io] Downloading ANT_A01_2011_laz_11.laz...
# Downloading ANT_A01_2011_laz_2.laz into directory data/raw/tiles/laz
# [io] Downloading ANT_A01_2011_laz_2.laz...
# Downloading ANT_A01_2011_laz_3.laz into directory data/raw/tiles/laz
# [io] Downloading ANT_A01_2011_laz_3.laz...
# Downloading ANT_A01_2011_laz_4.laz into directory data/raw/tiles/laz
# [io] Downloading ANT_A01_2011_laz_4.laz...
# Downloading ANT_A01_2011_laz_5.laz into directory data/raw/tiles/laz
# [io] Downloading ANT_A01_2011_laz_5.laz...
# Downloading ANT_A01_2011_laz_6.laz into directory data/raw/tiles/laz
# [io] Downloading ANT_A01_2011_laz_6.laz...
# Downloading ANT_A01_2011_laz_7.laz into directory data/raw/tiles/laz
# [io] Downloading ANT_A01_2011_laz_7.laz...
# Progress saved at 80/3152 files.
# Downloading ANT_A01_2011_laz_8.laz into directory data/raw/tiles/laz
# [io] Downloading ANT_A01_2011_laz_8.laz...
# Downloading ANT_A01_2011_laz_9.laz into directory data/raw/tiles/laz
# [io] Downloading ANT_A01_2011_laz_9.laz...
# Downloading ANTL5770C8970_cleaned.laz into directory data/raw/tiles/laz
# [io] Downloading ANTL5770C8970_cleaned.laz...
# Downloading ANTL5770C8971_cleaned.laz into directory data/raw/tiles/laz
# [io] Downloading ANTL5770C8971_cleaned.laz...
# Downloading ANTL5770C8972_cleaned.laz into directory data/raw/tiles/laz
# [io] Downloading ANTL5770C8972_cleaned.laz...
# Downloading ANTL5780C8970_cleaned.laz into directory data/raw/tiles/laz
# [io] Downloading ANTL5780C8970_cleaned.laz...
# Downloading ANTL5780C8971_cleaned.laz into directory data/raw/tiles/laz
# [io] Downloading ANTL5780C8971_cleaned.laz...
# Downloading ANTL5780C8972_cleaned.laz into directory data/raw/tiles/laz
# [io] Downloading ANTL5780C8972_cleaned.laz...
# [io] Failed to download ANTL5780C8972_cleaned.laz: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Failed for ANTL5780C8972_cleaned.laz: 'NoneType' object has no attribute 'read'
# Downloading ANTL5790C8970_cleaned.laz into directory data/raw/tiles/laz
# [io] Downloading ANTL5790C8970_cleaned.laz...
# Downloading ANTL5790C8971_cleaned.laz into directory data/raw/tiles/laz
# [io] Downloading ANTL5790C8971_cleaned.laz...
# Progress saved at 90/3152 files.
# Downloading ANTL5790C8972_cleaned.laz into directory data/raw/tiles/laz
# [io] Downloading ANTL5790C8972_cleaned.laz...
# Downloading ANTL5800C8970_cleaned.laz into directory data/raw/tiles/laz
# [io] Downloading ANTL5800C8970_cleaned.laz...
# Downloading ANTL5800C8971_cleaned.laz into directory data/raw/tiles/laz
# [io] Downloading ANTL5800C8971_cleaned.laz...
# Downloading ANTL5800C8972_cleaned.laz into directory data/raw/tiles/laz
# [io] Downloading ANTL5800C8972_cleaned.laz...
# Downloading BA3_A01_2014_laz_0.laz into directory data/raw/tiles/laz
# [io] Downloading BA3_A01_2014_laz_0.laz...
# Downloading BA3_A01_2014_laz_1.laz into directory data/raw/tiles/laz
# [io] Downloading BA3_A01_2014_laz_1.laz...
# Downloading BA3_A01_2014_laz_10.laz into directory data/raw/tiles/laz
# [io] Downloading BA3_A01_2014_laz_10.laz...
# Downloading BA3_A01_2014_laz_11.laz into directory data/raw/tiles/laz
# [io] Downloading BA3_A01_2014_laz_11.laz...
# Downloading BA3_A01_2014_laz_2.laz into directory data/raw/tiles/laz
# [io] Downloading BA3_A01_2014_laz_2.laz...
# Downloading BA3_A01_2014_laz_3.laz into directory data/raw/tiles/laz
# [io] Downloading BA3_A01_2014_laz_3.laz...
# Progress saved at 100/3152 files.
# Downloading BA3_A01_2014_laz_4.laz into directory data/raw/tiles/laz
# [io] Downloading BA3_A01_2014_laz_4.laz...
# Downloading BA3_A01_2014_laz_5.laz into directory data/raw/tiles/laz
# [io] Downloading BA3_A01_2014_laz_5.laz...
# Downloading BA3_A01_2014_laz_6.laz into directory data/raw/tiles/laz
# [io] Downloading BA3_A01_2014_laz_6.laz...
# Downloading BA3_A01_2014_laz_7.laz into directory data/raw/tiles/laz
# [io] Downloading BA3_A01_2014_laz_7.laz...
# Downloading BA3_A01_2014_laz_8.laz into directory data/raw/tiles/laz
# [io] Downloading BA3_A01_2014_laz_8.laz...
# Downloading BA3_A01_2014_laz_9.laz into directory data/raw/tiles/laz
# [io] Downloading BA3_A01_2014_laz_9.laz...
# Downloading BA3_A02_2014_laz_0.laz into directory data/raw/tiles/laz
# [io] Downloading BA3_A02_2014_laz_0.laz...
# Downloading BA3_A02_2014_laz_1.laz into directory data/raw/tiles/laz
# [io] Downloading BA3_A02_2014_laz_1.laz...
# Downloading BA3_A02_2014_laz_10.laz into directory data/raw/tiles/laz
# [io] Downloading BA3_A02_2014_laz_10.laz...
# Downloading BA3_A02_2014_laz_11.laz into directory data/raw/tiles/laz
# [io] Downloading BA3_A02_2014_laz_11.laz...
# Progress saved at 110/3152 files.
# Downloading BA3_A02_2014_laz_12.laz into directory data/raw/tiles/laz
# [io] Downloading BA3_A02_2014_laz_12.laz...
# Downloading BA3_A02_2014_laz_13.laz into directory data/raw/tiles/laz
# [io] Downloading BA3_A02_2014_laz_13.laz...
# Downloading BA3_A02_2014_laz_14.laz into directory data/raw/tiles/laz
# [io] Downloading BA3_A02_2014_laz_14.laz...
# Downloading BA3_A02_2014_laz_15.laz into directory data/raw/tiles/laz
# [io] Downloading BA3_A02_2014_laz_15.laz...
# Downloading BA3_A02_2014_laz_2.laz into directory data/raw/tiles/laz
# [io] Downloading BA3_A02_2014_laz_2.laz...
# Downloading BA3_A02_2014_laz_3.laz into directory data/raw/tiles/laz
# [io] Downloading BA3_A02_2014_laz_3.laz...
# Downloading BA3_A02_2014_laz_4.laz into directory data/raw/tiles/laz
# [io] Downloading BA3_A02_2014_laz_4.laz...
# Downloading BA3_A02_2014_laz_5.laz into directory data/raw/tiles/laz
# [io] Downloading BA3_A02_2014_laz_5.laz...
# Downloading BA3_A02_2014_laz_6.laz into directory data/raw/tiles/laz
# [io] Downloading BA3_A02_2014_laz_6.laz...
# Downloading BA3_A02_2014_laz_7.laz into directory data/raw/tiles/laz
# [io] Downloading BA3_A02_2014_laz_7.laz...
# Progress saved at 120/3152 files.
# Downloading BA3_A02_2014_laz_8.laz into directory data/raw/tiles/laz
# [io] Downloading BA3_A02_2014_laz_8.laz...
# Downloading BA3_A02_2014_laz_9.laz into directory data/raw/tiles/laz
# [io] Downloading BA3_A02_2014_laz_9.laz...
# Downloading BAR_A01_2014_laz_0.laz into directory data/raw/tiles/laz
# [io] Downloading BAR_A01_2014_laz_0.laz...
# Downloading BAR_A01_2014_laz_1.laz into directory data/raw/tiles/laz
# [io] Downloading BAR_A01_2014_laz_1.laz...
# Downloading BAR_A01_2014_laz_10.laz into directory data/raw/tiles/laz
# [io] Downloading BAR_A01_2014_laz_10.laz...
# Downloading BAR_A01_2014_laz_11.laz into directory data/raw/tiles/laz
# [io] Downloading BAR_A01_2014_laz_11.laz...
# Downloading BAR_A01_2014_laz_12.laz into directory data/raw/tiles/laz
# [io] Downloading BAR_A01_2014_laz_12.laz...
# Downloading BAR_A01_2014_laz_13.laz into directory data/raw/tiles/laz
# [io] Downloading BAR_A01_2014_laz_13.laz...
# Downloading BAR_A01_2014_laz_14.laz into directory data/raw/tiles/laz
# [io] Downloading BAR_A01_2014_laz_14.laz...
# Downloading BAR_A01_2014_laz_15.laz into directory data/raw/tiles/laz
# [io] Downloading BAR_A01_2014_laz_15.laz...
# Progress saved at 130/3152 files.
# Downloading BAR_A01_2014_laz_16.laz into directory data/raw/tiles/laz
# [io] Downloading BAR_A01_2014_laz_16.laz...
# Downloading BAR_A01_2014_laz_2.laz into directory data/raw/tiles/laz
# [io] Downloading BAR_A01_2014_laz_2.laz...
# Downloading BAR_A01_2014_laz_3.laz into directory data/raw/tiles/laz
# [io] Downloading BAR_A01_2014_laz_3.laz...
# Downloading BAR_A01_2014_laz_4.laz into directory data/raw/tiles/laz
# [io] Downloading BAR_A01_2014_laz_4.laz...
# Downloading BAR_A01_2014_laz_5.laz into directory data/raw/tiles/laz
# [io] Downloading BAR_A01_2014_laz_5.laz...
# Downloading BAR_A01_2014_laz_6.laz into directory data/raw/tiles/laz
# [io] Downloading BAR_A01_2014_laz_6.laz...
# Downloading BAR_A01_2014_laz_7.laz into directory data/raw/tiles/laz
# [io] Downloading BAR_A01_2014_laz_7.laz...
# Downloading BAR_A01_2014_laz_8.laz into directory data/raw/tiles/laz
# [io] Downloading BAR_A01_2014_laz_8.laz...
# Downloading BAR_A01_2014_laz_9.laz into directory data/raw/tiles/laz
# [io] Downloading BAR_A01_2014_laz_9.laz...
# Downloading BON_A01_2013_laz_0.laz into directory data/raw/tiles/laz
# [io] Downloading BON_A01_2013_laz_0.laz...
# Progress saved at 140/3152 files.
# Downloading BON_A01_2013_laz_1.laz into directory data/raw/tiles/laz
# [io] Downloading BON_A01_2013_laz_1.laz...
# Downloading BON_A01_2013_laz_10.laz into directory data/raw/tiles/laz
# [io] Downloading BON_A01_2013_laz_10.laz...
# Downloading BON_A01_2013_laz_11.laz into directory data/raw/tiles/laz
# [io] Downloading BON_A01_2013_laz_11.laz...
# Downloading BON_A01_2013_laz_12.laz into directory data/raw/tiles/laz
# [io] Downloading BON_A01_2013_laz_12.laz...
# Downloading BON_A01_2013_laz_13.laz into directory data/raw/tiles/laz
# [io] Downloading BON_A01_2013_laz_13.laz...
# Downloading BON_A01_2013_laz_2.laz into directory data/raw/tiles/laz
# [io] Downloading BON_A01_2013_laz_2.laz...
# [io] Failed to download BON_A01_2013_laz_2.laz: HTTPSConnectionPool(host='urs.earthdata.nasa.gov', port=443): Read timed out. (read timeout=5)
# Failed for BON_A01_2013_laz_2.laz: 'NoneType' object has no attribute 'read'
# Downloading BON_A01_2013_laz_3.laz into directory data/raw/tiles/laz
# [io] Downloading BON_A01_2013_laz_3.laz...
# Downloading BON_A01_2013_laz_4.laz into directory data/raw/tiles/laz
# [io] Downloading BON_A01_2013_laz_4.laz...
# Downloading BON_A01_2013_laz_5.laz into directory data/raw/tiles/laz
# [io] Downloading BON_A01_2013_laz_5.laz...
# Downloading BON_A01_2013_laz_6.laz into directory data/raw/tiles/laz
# [io] Downloading BON_A01_2013_laz_6.laz...
# Progress saved at 150/3152 files.
# Downloading BON_A01_2013_laz_7.laz into directory data/raw/tiles/laz
# [io] Downloading BON_A01_2013_laz_7.laz...
# Downloading BON_A01_2013_laz_8.laz into directory data/raw/tiles/laz
# [io] Downloading BON_A01_2013_laz_8.laz...
# Downloading BON_A01_2013_laz_9.laz into directory data/raw/tiles/laz
# [io] Downloading BON_A01_2013_laz_9.laz...
# Downloading BON_A01_2018_LAS_0.laz into directory data/raw/tiles/laz
# [io] Downloading BON_A01_2018_LAS_0.laz...
# Downloading BON_A01_2018_LAS_1.laz into directory data/raw/tiles/laz
# [io] Downloading BON_A01_2018_LAS_1.laz...
# Downloading BON_A01_2018_LAS_10.laz into directory data/raw/tiles/laz
# [io] Downloading BON_A01_2018_LAS_10.laz...
# Downloading BON_A01_2018_LAS_11.laz into directory data/raw/tiles/laz
# [io] Downloading BON_A01_2018_LAS_11.laz...
# Downloading BON_A01_2018_LAS_12.laz into directory data/raw/tiles/laz
# [io] Downloading BON_A01_2018_LAS_12.laz...
# Downloading BON_A01_2018_LAS_2.laz into directory data/raw/tiles/laz
# [io] Downloading BON_A01_2018_LAS_2.laz...
# Downloading BON_A01_2018_LAS_3.laz into directory data/raw/tiles/laz
# [io] Downloading BON_A01_2018_LAS_3.laz...
# Progress saved at 160/3152 files.
# Downloading BON_A01_2018_LAS_4.laz into directory data/raw/tiles/laz
# [io] Downloading BON_A01_2018_LAS_4.laz...
# Downloading BON_A01_2018_LAS_5.laz into directory data/raw/tiles/laz
# [io] Downloading BON_A01_2018_LAS_5.laz...
# Downloading BON_A01_2018_LAS_6.laz into directory data/raw/tiles/laz
# [io] Downloading BON_A01_2018_LAS_6.laz...
# Downloading BON_A01_2018_LAS_7.laz into directory data/raw/tiles/laz
# [io] Downloading BON_A01_2018_LAS_7.laz...
# Downloading BON_A01_2018_LAS_8.laz into directory data/raw/tiles/laz
# [io] Downloading BON_A01_2018_LAS_8.laz...
# Downloading BON_A01_2018_LAS_9.laz into directory data/raw/tiles/laz
# [io] Downloading BON_A01_2018_LAS_9.laz...
# Downloading CAG_A01_2013_laz_0.laz into directory data/raw/tiles/laz
# [io] Downloading CAG_A01_2013_laz_0.laz...
# Downloading CAG_A01_2013_laz_1.laz into directory data/raw/tiles/laz
# [io] Downloading CAG_A01_2013_laz_1.laz...
# Downloading CAG_A01_2013_laz_10.laz into directory data/raw/tiles/laz
# [io] Downloading CAG_A01_2013_laz_10.laz...
# Downloading CAG_A01_2013_laz_11.laz into directory data/raw/tiles/laz
# [io] Downloading CAG_A01_2013_laz_11.laz...
# Progress saved at 170/3152 files.
# Downloading CAG_A01_2013_laz_12.laz into directory data/raw/tiles/laz
# [io] Downloading CAG_A01_2013_laz_12.laz...
# Downloading CAG_A01_2013_laz_13.laz into directory data/raw/tiles/laz
# [io] Downloading CAG_A01_2013_laz_13.laz...
# Downloading CAG_A01_2013_laz_14.laz into directory data/raw/tiles/laz
# [io] Downloading CAG_A01_2013_laz_14.laz...
# Downloading CAG_A01_2013_laz_15.laz into directory data/raw/tiles/laz
# [io] Downloading CAG_A01_2013_laz_15.laz...
# Downloading CAG_A01_2013_laz_16.laz into directory data/raw/tiles/laz
# [io] Downloading CAG_A01_2013_laz_16.laz...
# Downloading CAG_A01_2013_laz_17.laz into directory data/raw/tiles/laz
# [io] Downloading CAG_A01_2013_laz_17.laz...
# Downloading CAG_A01_2013_laz_18.laz into directory data/raw/tiles/laz
# [io] Downloading CAG_A01_2013_laz_18.laz...
# Downloading CAG_A01_2013_laz_19.laz into directory data/raw/tiles/laz
# [io] Downloading CAG_A01_2013_laz_19.laz...
# Downloading CAG_A01_2013_laz_2.laz into directory data/raw/tiles/laz
# [io] Downloading CAG_A01_2013_laz_2.laz...
# Downloading CAG_A01_2013_laz_3.laz into directory data/raw/tiles/laz
# [io] Downloading CAG_A01_2013_laz_3.laz...
# Progress saved at 180/3152 files.
# Downloading CAG_A01_2013_laz_4.laz into directory data/raw/tiles/laz
# [io] Downloading CAG_A01_2013_laz_4.laz...
# Downloading CAG_A01_2013_laz_5.laz into directory data/raw/tiles/laz
# [io] Downloading CAG_A01_2013_laz_5.laz...
# Downloading CAG_A01_2013_laz_6.laz into directory data/raw/tiles/laz
# [io] Downloading CAG_A01_2013_laz_6.laz...
# Downloading CAG_A01_2013_laz_7.laz into directory data/raw/tiles/laz
# [io] Downloading CAG_A01_2013_laz_7.laz...
# Downloading CAG_A01_2013_laz_8.laz into directory data/raw/tiles/laz
# [io] Downloading CAG_A01_2013_laz_8.laz...
# Downloading CAG_A01_2013_laz_9.laz into directory data/raw/tiles/laz
# [io] Downloading CAG_A01_2013_laz_9.laz...
# Downloading CAN_A01_2014_laz_0.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A01_2014_laz_0.laz...
# Downloading CAN_A01_2014_laz_1.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A01_2014_laz_1.laz...
# Downloading CAN_A01_2014_laz_10.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A01_2014_laz_10.laz...
# Downloading CAN_A01_2014_laz_11.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A01_2014_laz_11.laz...
# Progress saved at 190/3152 files.
# Downloading CAN_A01_2014_laz_2.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A01_2014_laz_2.laz...
# Downloading CAN_A01_2014_laz_3.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A01_2014_laz_3.laz...
# Downloading CAN_A01_2014_laz_4.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A01_2014_laz_4.laz...
# Downloading CAN_A01_2014_laz_5.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A01_2014_laz_5.laz...
# Downloading CAN_A01_2014_laz_6.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A01_2014_laz_6.laz...
# Downloading CAN_A01_2014_laz_7.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A01_2014_laz_7.laz...
# Downloading CAN_A01_2014_laz_8.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A01_2014_laz_8.laz...
# Downloading CAN_A01_2014_laz_9.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A01_2014_laz_9.laz...
# Downloading CAN_A02_2014_laz_0.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A02_2014_laz_0.laz...
# Downloading CAN_A02_2014_laz_1.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A02_2014_laz_1.laz...
# Progress saved at 200/3152 files.
# Downloading CAN_A02_2014_laz_10.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A02_2014_laz_10.laz...
# Downloading CAN_A02_2014_laz_11.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A02_2014_laz_11.laz...
# Downloading CAN_A02_2014_laz_2.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A02_2014_laz_2.laz...
# Downloading CAN_A02_2014_laz_3.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A02_2014_laz_3.laz...
# Downloading CAN_A02_2014_laz_4.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A02_2014_laz_4.laz...
# Downloading CAN_A02_2014_laz_5.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A02_2014_laz_5.laz...
# Downloading CAN_A02_2014_laz_6.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A02_2014_laz_6.laz...
# Downloading CAN_A02_2014_laz_7.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A02_2014_laz_7.laz...
# Downloading CAN_A02_2014_laz_8.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A02_2014_laz_8.laz...
# Downloading CAN_A02_2014_laz_9.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A02_2014_laz_9.laz...
# Progress saved at 210/3152 files.
# Downloading CAN_A02_2017_LAS_0.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A02_2017_LAS_0.laz...
# Downloading CAN_A02_2017_LAS_1.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A02_2017_LAS_1.laz...
# Downloading CAN_A02_2017_LAS_10.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A02_2017_LAS_10.laz...
# Downloading CAN_A02_2017_LAS_11.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A02_2017_LAS_11.laz...
# Downloading CAN_A02_2017_LAS_2.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A02_2017_LAS_2.laz...
# Downloading CAN_A02_2017_LAS_3.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A02_2017_LAS_3.laz...
# Downloading CAN_A02_2017_LAS_4.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A02_2017_LAS_4.laz...
# Downloading CAN_A02_2017_LAS_5.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A02_2017_LAS_5.laz...
# Downloading CAN_A02_2017_LAS_6.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A02_2017_LAS_6.laz...
# Downloading CAN_A02_2017_LAS_7.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A02_2017_LAS_7.laz...
# Progress saved at 220/3152 files.
# Downloading CAN_A02_2017_LAS_8.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A02_2017_LAS_8.laz...
# Downloading CAN_A02_2017_LAS_9.laz into directory data/raw/tiles/laz
# [io] Downloading CAN_A02_2017_LAS_9.laz...
# Downloading CAU_A01_2012_laz_0.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2012_laz_0.laz...
# Downloading CAU_A01_2012_laz_1.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2012_laz_1.laz...
# Downloading CAU_A01_2012_laz_10.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2012_laz_10.laz...
# Downloading CAU_A01_2012_laz_11.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2012_laz_11.laz...
# Downloading CAU_A01_2012_laz_12.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2012_laz_12.laz...
# Downloading CAU_A01_2012_laz_13.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2012_laz_13.laz...
# Downloading CAU_A01_2012_laz_14.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2012_laz_14.laz...
# Downloading CAU_A01_2012_laz_15.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2012_laz_15.laz...
# Progress saved at 230/3152 files.
# Downloading CAU_A01_2012_laz_16.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2012_laz_16.laz...
# Downloading CAU_A01_2012_laz_17.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2012_laz_17.laz...
# Downloading CAU_A01_2012_laz_18.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2012_laz_18.laz...
# Downloading CAU_A01_2012_laz_19.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2012_laz_19.laz...
# Downloading CAU_A01_2012_laz_2.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2012_laz_2.laz...
# Downloading CAU_A01_2012_laz_3.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2012_laz_3.laz...
# Downloading CAU_A01_2012_laz_4.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2012_laz_4.laz...
# Downloading CAU_A01_2012_laz_5.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2012_laz_5.laz...
# Downloading CAU_A01_2012_laz_6.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2012_laz_6.laz...
# Downloading CAU_A01_2012_laz_7.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2012_laz_7.laz...
# Progress saved at 240/3152 files.
# Downloading CAU_A01_2012_laz_8.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2012_laz_8.laz...
# Downloading CAU_A01_2012_laz_9.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2012_laz_9.laz...
# Downloading CAU_A01_2014_laz_0.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2014_laz_0.laz...
# Downloading CAU_A01_2014_laz_1.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2014_laz_1.laz...
# Downloading CAU_A01_2014_laz_10.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2014_laz_10.laz...
# Downloading CAU_A01_2014_laz_11.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2014_laz_11.laz...
# Downloading CAU_A01_2014_laz_12.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2014_laz_12.laz...
# Downloading CAU_A01_2014_laz_13.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2014_laz_13.laz...
# Downloading CAU_A01_2014_laz_14.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2014_laz_14.laz...
# Downloading CAU_A01_2014_laz_15.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2014_laz_15.laz...
# Progress saved at 250/3152 files.
# Downloading CAU_A01_2014_laz_16.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2014_laz_16.laz...
# Downloading CAU_A01_2014_laz_17.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2014_laz_17.laz...
# Downloading CAU_A01_2014_laz_18.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2014_laz_18.laz...
# Downloading CAU_A01_2014_laz_19.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2014_laz_19.laz...
# Downloading CAU_A01_2014_laz_2.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2014_laz_2.laz...
# Downloading CAU_A01_2014_laz_3.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2014_laz_3.laz...
# Downloading CAU_A01_2014_laz_4.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2014_laz_4.laz...
# Downloading CAU_A01_2014_laz_5.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2014_laz_5.laz...
# Downloading CAU_A01_2014_laz_6.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2014_laz_6.laz...
# Downloading CAU_A01_2014_laz_7.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2014_laz_7.laz...
# Progress saved at 260/3152 files.
# Downloading CAU_A01_2014_laz_8.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2014_laz_8.laz...
# Downloading CAU_A01_2014_laz_9.laz into directory data/raw/tiles/laz
# [io] Downloading CAU_A01_2014_laz_9.laz...
# Downloading CON_A01_2015_LAS_0.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_0.laz...
# Downloading CON_A01_2015_LAS_1.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_1.laz...
# Downloading CON_A01_2015_LAS_10.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_10.laz...
# Downloading CON_A01_2015_LAS_100.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_100.laz...
# Downloading CON_A01_2015_LAS_101.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_101.laz...
# Downloading CON_A01_2015_LAS_102.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_102.laz...
# Downloading CON_A01_2015_LAS_103.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_103.laz...
# Downloading CON_A01_2015_LAS_104.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_104.laz...
# Progress saved at 270/3152 files.
# Downloading CON_A01_2015_LAS_105.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_105.laz...
# Downloading CON_A01_2015_LAS_106.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_106.laz...
# Downloading CON_A01_2015_LAS_107.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_107.laz...
# Downloading CON_A01_2015_LAS_108.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_108.laz...
# Downloading CON_A01_2015_LAS_109.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_109.laz...
# Downloading CON_A01_2015_LAS_11.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_11.laz...
# Downloading CON_A01_2015_LAS_110.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_110.laz...
# Downloading CON_A01_2015_LAS_111.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_111.laz...
# Downloading CON_A01_2015_LAS_112.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_112.laz...
# Downloading CON_A01_2015_LAS_113.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_113.laz...
# Progress saved at 280/3152 files.
# Downloading CON_A01_2015_LAS_114.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_114.laz...
# Downloading CON_A01_2015_LAS_115.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_115.laz...
# Downloading CON_A01_2015_LAS_116.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_116.laz...
# Downloading CON_A01_2015_LAS_117.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_117.laz...
# Downloading CON_A01_2015_LAS_118.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_118.laz...
# Downloading CON_A01_2015_LAS_119.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_119.laz...
# Downloading CON_A01_2015_LAS_12.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_12.laz...
# Downloading CON_A01_2015_LAS_120.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_120.laz...
# Downloading CON_A01_2015_LAS_121.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_121.laz...
# Downloading CON_A01_2015_LAS_122.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_122.laz...
# Progress saved at 290/3152 files.
# Downloading CON_A01_2015_LAS_123.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_123.laz...
# Downloading CON_A01_2015_LAS_124.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_124.laz...
# Downloading CON_A01_2015_LAS_125.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_125.laz...
# Downloading CON_A01_2015_LAS_126.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_126.laz...
# Downloading CON_A01_2015_LAS_127.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_127.laz...
# Downloading CON_A01_2015_LAS_128.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_128.laz...
# Downloading CON_A01_2015_LAS_129.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_129.laz...
# Downloading CON_A01_2015_LAS_13.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_13.laz...
# Downloading CON_A01_2015_LAS_130.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_130.laz...
# Downloading CON_A01_2015_LAS_131.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_131.laz...
# Progress saved at 300/3152 files.
# Downloading CON_A01_2015_LAS_132.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_132.laz...
# Downloading CON_A01_2015_LAS_133.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_133.laz...
# Downloading CON_A01_2015_LAS_134.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_134.laz...
# Downloading CON_A01_2015_LAS_135.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_135.laz...
# Downloading CON_A01_2015_LAS_136.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_136.laz...
# Downloading CON_A01_2015_LAS_137.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_137.laz...
# Downloading CON_A01_2015_LAS_138.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_138.laz...
# Downloading CON_A01_2015_LAS_139.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_139.laz...
# Downloading CON_A01_2015_LAS_14.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_14.laz...
# Downloading CON_A01_2015_LAS_140.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_140.laz...
# Progress saved at 310/3152 files.
# Downloading CON_A01_2015_LAS_141.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_141.laz...
# Downloading CON_A01_2015_LAS_142.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_142.laz...
# Downloading CON_A01_2015_LAS_143.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_143.laz...
# Downloading CON_A01_2015_LAS_144.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_144.laz...
# Downloading CON_A01_2015_LAS_145.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_145.laz...
# Downloading CON_A01_2015_LAS_146.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_146.laz...
# Downloading CON_A01_2015_LAS_147.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_147.laz...
# Downloading CON_A01_2015_LAS_148.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_148.laz...
# Downloading CON_A01_2015_LAS_149.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_149.laz...
# Downloading CON_A01_2015_LAS_15.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_15.laz...
# Progress saved at 320/3152 files.
# Downloading CON_A01_2015_LAS_150.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_150.laz...
# Downloading CON_A01_2015_LAS_151.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_151.laz...
# Downloading CON_A01_2015_LAS_152.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_152.laz...
# Downloading CON_A01_2015_LAS_153.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_153.laz...
# Downloading CON_A01_2015_LAS_154.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_154.laz...
# Downloading CON_A01_2015_LAS_155.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_155.laz...
# Downloading CON_A01_2015_LAS_156.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_156.laz...
# Downloading CON_A01_2015_LAS_157.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_157.laz...
# Downloading CON_A01_2015_LAS_158.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_158.laz...
# Downloading CON_A01_2015_LAS_159.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_159.laz...
# Progress saved at 330/3152 files.
# Downloading CON_A01_2015_LAS_16.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_16.laz...
# Downloading CON_A01_2015_LAS_160.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_160.laz...
# Downloading CON_A01_2015_LAS_161.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_161.laz...
# Downloading CON_A01_2015_LAS_162.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_162.laz...
# Downloading CON_A01_2015_LAS_163.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_163.laz...
# Downloading CON_A01_2015_LAS_164.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_164.laz...
# Downloading CON_A01_2015_LAS_165.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_165.laz...
# Downloading CON_A01_2015_LAS_166.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_166.laz...
# Downloading CON_A01_2015_LAS_167.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_167.laz...
# Downloading CON_A01_2015_LAS_168.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_168.laz...
# Progress saved at 340/3152 files.
# Downloading CON_A01_2015_LAS_169.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_169.laz...
# Downloading CON_A01_2015_LAS_17.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_17.laz...
# Downloading CON_A01_2015_LAS_170.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_170.laz...
# Downloading CON_A01_2015_LAS_171.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_171.laz...
# Downloading CON_A01_2015_LAS_172.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_172.laz...
# Downloading CON_A01_2015_LAS_173.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_173.laz...
# Downloading CON_A01_2015_LAS_175.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_175.laz...
# Downloading CON_A01_2015_LAS_176.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_176.laz...
# Downloading CON_A01_2015_LAS_177.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_177.laz...
# Downloading CON_A01_2015_LAS_178.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_178.laz...
# Progress saved at 350/3152 files.
# Downloading CON_A01_2015_LAS_179.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_179.laz...
# Downloading CON_A01_2015_LAS_18.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_18.laz...
# Downloading CON_A01_2015_LAS_180.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_180.laz...
# Downloading CON_A01_2015_LAS_181.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_181.laz...
# Downloading CON_A01_2015_LAS_182.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_182.laz...
# Downloading CON_A01_2015_LAS_183.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_183.laz...
# Downloading CON_A01_2015_LAS_184.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_184.laz...
# Downloading CON_A01_2015_LAS_185.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_185.laz...
# Downloading CON_A01_2015_LAS_186.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_186.laz...
# Downloading CON_A01_2015_LAS_187.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_187.laz...
# Progress saved at 360/3152 files.
# Downloading CON_A01_2015_LAS_188.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_188.laz...
# Downloading CON_A01_2015_LAS_189.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_189.laz...
# Downloading CON_A01_2015_LAS_19.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_19.laz...
# Downloading CON_A01_2015_LAS_190.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_190.laz...
# Downloading CON_A01_2015_LAS_191.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_191.laz...
# Downloading CON_A01_2015_LAS_192.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_192.laz...
# Downloading CON_A01_2015_LAS_193.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_193.laz...
# Downloading CON_A01_2015_LAS_194.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_194.laz...
# Downloading CON_A01_2015_LAS_195.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_195.laz...
# Downloading CON_A01_2015_LAS_196.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_196.laz...
# Progress saved at 370/3152 files.
# Downloading CON_A01_2015_LAS_197.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_197.laz...
# Downloading CON_A01_2015_LAS_198.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_198.laz...
# Downloading CON_A01_2015_LAS_199.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_199.laz...
# Downloading CON_A01_2015_LAS_2.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_2.laz...
# Downloading CON_A01_2015_LAS_20.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_20.laz...
# Downloading CON_A01_2015_LAS_200.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_200.laz...
# Downloading CON_A01_2015_LAS_201.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_201.laz...
# Downloading CON_A01_2015_LAS_202.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_202.laz...
# Downloading CON_A01_2015_LAS_203.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_203.laz...
# Downloading CON_A01_2015_LAS_204.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_204.laz...
# Progress saved at 380/3152 files.
# Downloading CON_A01_2015_LAS_205.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_205.laz...
# Downloading CON_A01_2015_LAS_206.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_206.laz...
# Downloading CON_A01_2015_LAS_207.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_207.laz...
# Downloading CON_A01_2015_LAS_208.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_208.laz...
# Downloading CON_A01_2015_LAS_209.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_209.laz...
# Downloading CON_A01_2015_LAS_21.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_21.laz...
# Downloading CON_A01_2015_LAS_210.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_210.laz...
# Downloading CON_A01_2015_LAS_211.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_211.laz...
# Downloading CON_A01_2015_LAS_212.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_212.laz...
# Downloading CON_A01_2015_LAS_213.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_213.laz...
# Progress saved at 390/3152 files.
# Downloading CON_A01_2015_LAS_214.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_214.laz...
# Downloading CON_A01_2015_LAS_215.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_215.laz...
# Downloading CON_A01_2015_LAS_216.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_216.laz...
# Downloading CON_A01_2015_LAS_217.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_217.laz...
# Downloading CON_A01_2015_LAS_22.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_22.laz...
# Downloading CON_A01_2015_LAS_23.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_23.laz...
# Downloading CON_A01_2015_LAS_24.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_24.laz...
# Downloading CON_A01_2015_LAS_25.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_25.laz...
# Downloading CON_A01_2015_LAS_26.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_26.laz...
# Downloading CON_A01_2015_LAS_27.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_27.laz...
# Progress saved at 400/3152 files.
# Downloading CON_A01_2015_LAS_28.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_28.laz...
# Downloading CON_A01_2015_LAS_29.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_29.laz...
# Downloading CON_A01_2015_LAS_3.laz into directory data/raw/tiles/laz
# [io] Downloading CON_A01_2015_LAS_3.laz...
# ...
# [io] Downloading TAP_A01_2012_laz_13.laz...
# Downloading TAP_A01_2012_laz_14.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A01_2012_laz_14.laz...
# Downloading TAP_A01_2012_laz_15.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A01_2012_laz_15.laz...
# Downloading TAP_A01_2012_laz_16.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A01_2012_laz_16.laz...
# Downloading TAP_A01_2012_laz_2.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A01_2012_laz_2.laz...
# Downloading TAP_A01_2012_laz_3.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A01_2012_laz_3.laz...
# Progress saved at 3020/3152 files.
# Downloading TAP_A01_2012_laz_4.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A01_2012_laz_4.laz...
# Downloading TAP_A01_2012_laz_5.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A01_2012_laz_5.laz...
# Downloading TAP_A01_2012_laz_6.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A01_2012_laz_6.laz...
# Downloading TAP_A01_2012_laz_7.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A01_2012_laz_7.laz...
# Downloading TAP_A01_2012_laz_8.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A01_2012_laz_8.laz...
# Downloading TAP_A01_2012_laz_9.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A01_2012_laz_9.laz...
# Downloading TAP_A02_2012_laz_0.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2012_laz_0.laz...
# Downloading TAP_A02_2012_laz_1.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2012_laz_1.laz...
# Downloading TAP_A02_2012_laz_2.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2012_laz_2.laz...
# Downloading TAP_A02_2012_laz_3.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2012_laz_3.laz...
# Progress saved at 3030/3152 files.
# Downloading TAP_A02_2012_laz_4.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2012_laz_4.laz...
# Downloading TAP_A02_2012_laz_5.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2012_laz_5.laz...
# Downloading TAP_A02_2012_laz_6.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2012_laz_6.laz...
# Downloading TAP_A02_2012_laz_7.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2012_laz_7.laz...
# Downloading TAP_A02_2013_laz_0.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2013_laz_0.laz...
# Downloading TAP_A02_2013_laz_1.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2013_laz_1.laz...
# Downloading TAP_A02_2013_laz_2.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2013_laz_2.laz...
# Downloading TAP_A02_2013_laz_3.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2013_laz_3.laz...
# Downloading TAP_A02_2013_laz_4.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2013_laz_4.laz...
# Downloading TAP_A02_2013_laz_5.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2013_laz_5.laz...
# Progress saved at 3040/3152 files.
# Downloading TAP_A02_2013_laz_6.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2013_laz_6.laz...
# Downloading TAP_A02_2013_laz_7.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2013_laz_7.laz...
# Downloading TAP_A02_2016_laz_0.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2016_laz_0.laz...
# Downloading TAP_A02_2016_laz_1.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2016_laz_1.laz...
# Downloading TAP_A02_2016_laz_2.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2016_laz_2.laz...
# Downloading TAP_A02_2016_laz_3.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2016_laz_3.laz...
# Downloading TAP_A02_2016_laz_4.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2016_laz_4.laz...
# Downloading TAP_A02_2016_laz_5.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2016_laz_5.laz...
# Downloading TAP_A02_2016_laz_6.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2016_laz_6.laz...
# Downloading TAP_A02_2016_laz_7.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2016_laz_7.laz...
# Progress saved at 3050/3152 files.
# Downloading TAP_A02_2018_LAS_0.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2018_LAS_0.laz...
# Downloading TAP_A02_2018_LAS_1.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2018_LAS_1.laz...
# Downloading TAP_A02_2018_LAS_2.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2018_LAS_2.laz...
# Downloading TAP_A02_2018_LAS_3.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2018_LAS_3.laz...
# Downloading TAP_A02_2018_LAS_4.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2018_LAS_4.laz...
# Downloading TAP_A02_2018_LAS_5.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2018_LAS_5.laz...
# Downloading TAP_A02_2018_LAS_6.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2018_LAS_6.laz...
# Downloading TAP_A02_2018_LAS_7.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A02_2018_LAS_7.laz...
# Downloading TAP_A03_2012_laz_0.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2012_laz_0.laz...
# Downloading TAP_A03_2012_laz_1.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2012_laz_1.laz...
# Progress saved at 3060/3152 files.
# Downloading TAP_A03_2012_laz_10.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2012_laz_10.laz...
# Downloading TAP_A03_2012_laz_11.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2012_laz_11.laz...
# Downloading TAP_A03_2012_laz_12.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2012_laz_12.laz...
# Downloading TAP_A03_2012_laz_13.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2012_laz_13.laz...
# Downloading TAP_A03_2012_laz_14.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2012_laz_14.laz...
# Downloading TAP_A03_2012_laz_15.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2012_laz_15.laz...
# Downloading TAP_A03_2012_laz_16.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2012_laz_16.laz...
# Downloading TAP_A03_2012_laz_2.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2012_laz_2.laz...
# Downloading TAP_A03_2012_laz_3.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2012_laz_3.laz...
# Downloading TAP_A03_2012_laz_4.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2012_laz_4.laz...
# Progress saved at 3070/3152 files.
# Downloading TAP_A03_2012_laz_5.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2012_laz_5.laz...
# Downloading TAP_A03_2012_laz_6.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2012_laz_6.laz...
# Downloading TAP_A03_2012_laz_7.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2012_laz_7.laz...
# Downloading TAP_A03_2012_laz_8.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2012_laz_8.laz...
# Downloading TAP_A03_2012_laz_9.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2012_laz_9.laz...
# Downloading TAP_A03_2013_laz_0.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2013_laz_0.laz...
# Downloading TAP_A03_2013_laz_1.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2013_laz_1.laz...
# Downloading TAP_A03_2013_laz_10.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2013_laz_10.laz...
# Downloading TAP_A03_2013_laz_11.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2013_laz_11.laz...
# Downloading TAP_A03_2013_laz_12.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2013_laz_12.laz...
# Progress saved at 3080/3152 files.
# Downloading TAP_A03_2013_laz_13.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2013_laz_13.laz...
# Downloading TAP_A03_2013_laz_14.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2013_laz_14.laz...
# Downloading TAP_A03_2013_laz_15.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2013_laz_15.laz...
# Downloading TAP_A03_2013_laz_16.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2013_laz_16.laz...
# Downloading TAP_A03_2013_laz_2.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2013_laz_2.laz...
# Downloading TAP_A03_2013_laz_3.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2013_laz_3.laz...
# Downloading TAP_A03_2013_laz_4.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2013_laz_4.laz...
# Downloading TAP_A03_2013_laz_5.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2013_laz_5.laz...
# Downloading TAP_A03_2013_laz_6.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2013_laz_6.laz...
# Downloading TAP_A03_2013_laz_7.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2013_laz_7.laz...
# Progress saved at 3090/3152 files.
# Downloading TAP_A03_2013_laz_8.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2013_laz_8.laz...
# Downloading TAP_A03_2013_laz_9.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2013_laz_9.laz...
# Downloading TAP_A03_2016_laz_0.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2016_laz_0.laz...
# Downloading TAP_A03_2016_laz_1.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2016_laz_1.laz...
# Downloading TAP_A03_2016_laz_10.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2016_laz_10.laz...
# Downloading TAP_A03_2016_laz_11.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2016_laz_11.laz...
# Downloading TAP_A03_2016_laz_12.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2016_laz_12.laz...
# Downloading TAP_A03_2016_laz_13.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2016_laz_13.laz...
# Downloading TAP_A03_2016_laz_14.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2016_laz_14.laz...
# Downloading TAP_A03_2016_laz_15.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2016_laz_15.laz...
# Progress saved at 3100/3152 files.
# Downloading TAP_A03_2016_laz_16.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2016_laz_16.laz...
# Downloading TAP_A03_2016_laz_2.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2016_laz_2.laz...
# Downloading TAP_A03_2016_laz_3.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2016_laz_3.laz...
# Downloading TAP_A03_2016_laz_4.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2016_laz_4.laz...
# Downloading TAP_A03_2016_laz_5.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2016_laz_5.laz...
# Downloading TAP_A03_2016_laz_6.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2016_laz_6.laz...
# Downloading TAP_A03_2016_laz_7.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2016_laz_7.laz...
# Downloading TAP_A03_2016_laz_8.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2016_laz_8.laz...
# Downloading TAP_A03_2016_laz_9.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2016_laz_9.laz...
# Downloading TAP_A03_2018_LAS_0.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2018_LAS_0.laz...
# Progress saved at 3110/3152 files.
# Downloading TAP_A03_2018_LAS_1.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2018_LAS_1.laz...
# Downloading TAP_A03_2018_LAS_10.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2018_LAS_10.laz...
# Downloading TAP_A03_2018_LAS_11.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2018_LAS_11.laz...
# Downloading TAP_A03_2018_LAS_2.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2018_LAS_2.laz...
# Downloading TAP_A03_2018_LAS_3.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2018_LAS_3.laz...
# Downloading TAP_A03_2018_LAS_4.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2018_LAS_4.laz...
# Downloading TAP_A03_2018_LAS_5.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2018_LAS_5.laz...
# Downloading TAP_A03_2018_LAS_6.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2018_LAS_6.laz...
# Downloading TAP_A03_2018_LAS_7.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2018_LAS_7.laz...
# Downloading TAP_A03_2018_LAS_8.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2018_LAS_8.laz...
# Progress saved at 3120/3152 files.
# Downloading TAP_A03_2018_LAS_9.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A03_2018_LAS_9.laz...
# Downloading TAP_A04_2008_15-01.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A04_2008_15-01.laz...
# Downloading TAP_A04_2008_15-02.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A04_2008_15-02.laz...
# Downloading TAP_A04_2008_15-03.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A04_2008_15-03.laz...
# Downloading TAP_A04_2008_15-04.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A04_2008_15-04.laz...
# Downloading TAP_A04_2008_laz_0.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A04_2008_laz_0.laz...
# Downloading TAP_A04_2008_laz_1.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A04_2008_laz_1.laz...
# Downloading TAP_A04_2008_laz_2.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A04_2008_laz_2.laz...
# Downloading TAP_A04_2008_laz_3.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A04_2008_laz_3.laz...
# Downloading TAP_A04_2018_LAS_0.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A04_2018_LAS_0.laz...
# Progress saved at 3130/3152 files.
# Downloading TAP_A04_2018_LAS_1.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A04_2018_LAS_1.laz...
# Downloading TAP_A04_2018_LAS_10.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A04_2018_LAS_10.laz...
# Downloading TAP_A04_2018_LAS_11.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A04_2018_LAS_11.laz...
# Downloading TAP_A04_2018_LAS_12.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A04_2018_LAS_12.laz...
# Downloading TAP_A04_2018_LAS_2.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A04_2018_LAS_2.laz...
# Downloading TAP_A04_2018_LAS_3.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A04_2018_LAS_3.laz...
# Downloading TAP_A04_2018_LAS_4.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A04_2018_LAS_4.laz...
# Downloading TAP_A04_2018_LAS_5.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A04_2018_LAS_5.laz...
# Downloading TAP_A04_2018_LAS_6.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A04_2018_LAS_6.laz...
# Downloading TAP_A04_2018_LAS_7.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A04_2018_LAS_7.laz...
# Progress saved at 3140/3152 files.
# Downloading TAP_A04_2018_LAS_8.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A04_2018_LAS_8.laz...
# Downloading TAP_A04_2018_LAS_9.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A04_2018_LAS_9.laz...
# Downloading TAP_A05_2008_16-01.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A05_2008_16-01.laz...
# Downloading TAP_A05_2008_laz_0.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A05_2008_laz_0.laz...
# Downloading TAP_A05_2018_LAS_0.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A05_2018_LAS_0.laz...
# Downloading TAP_A05_2018_LAS_1.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A05_2018_LAS_1.laz...
# Downloading TAP_A05_2018_LAS_2.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A05_2018_LAS_2.laz...
# Downloading TAP_A06_2008_17-01.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A06_2008_17-01.laz...
# Downloading TAP_A06_2008_laz_0.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A06_2008_laz_0.laz...
# Downloading TAP_A06_2018_LAS_0.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A06_2018_LAS_0.laz...
# Progress saved at 3150/3152 files.
# Downloading TAP_A06_2018_LAS_1.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A06_2018_LAS_1.laz...
# Downloading TAP_A06_2018_LAS_2.laz into directory data/raw/tiles/laz
# [io] Downloading TAP_A06_2018_LAS_2.laz...
# Progress saved at 3152/3152 files.
# DONE and saved to temp.csv
